# %% [markdown]
# ---
#
#
# # Assignment: Introduction to Python
# # Name:
# # Roll No:
#
#
# ---
#
#
#
# # Instructions:
# # 1. Do not modify given code unless asked
# # 2. Write your answer in marked sections
# # 3. Run all cells before submitting

# %% [markdown]
# ## <font color='red'> You are requested not to touch next two cell. The following two cell is used for supporting file.

# %%
# !wget https://raw.githubusercontent.com/TumpaBanerjee/Value-Added-Training-Program/main/Day2/utils.py

# %%
import utils

# %% [markdown]
# ## Introduction
# How to use this Notebook
#
# Do not change content of any cell unless you are asking to do.
# You have to add one or two line of code in the cell followed by the markdown "Question".
#
# Next to exercise cell there is a testing cell which will test your code.
#
# ### <font color='red'> Replace your code with None
#
# _______________________________________________________________

# %% [markdown]
# # Question 1
# ## Write a program to find the factorial value of a number $num$.
# $num!=num*(num-1)*(num-1)*...*1$

# %%
def calculate_factorial(num):
  """
This functions will calculate factorial of a number num and return the factorial of num as fact
  """
  # initialize the variable i with num, i will be multiplied and reduced by 1
  i=num

    # initialize the fact variable with 1
  fact=1
  while i>0:   # multiplication will be done until num reaches to 1
      fact=None   # multiply fact by i
      i=None     # reduced the number by 1
  return fact

# %% [markdown]
# ## Test your code

# %%
print(calculate_factorial(5))

# %% [markdown]
# #### Output of the following cell will come as
#
# All test cases passed

# %%
utils.test_calculate_factorial(calculate_factorial)

# %% [markdown]
# # Question 2
# ## Write a program to calculate sum of digits of a number $num$.
# num=246
# sum=6+4+2=12
#
# **Logic**:
#
# sum=0
#
# Condition       digit           sum            num
#
# 246>0            246%10=6          0+6=6       246//10=24
#
# 24>0             25%10=4           6+4=10       24//10=2
#
# 2>0              2%10=2            10+2=12      2//10=0
#
# 0!>0(condition False)

# %%
def sum_of_digits(num):
  """
This function will calculate sum of digits of a number num and return the sum of digits of num as sum1
  """
  sum1=0  # initialize sum to zero
  # the following loop will extract least significant digit, add the digit and update the number removing last digit
  while num>0:
      digit=num%10      # extract least significant digit
      None
      None       # add the digit
             # update the number after removing last digit

  return sum1

# %% [markdown]
# ## Test your code

# %%
print(sum_of_digits(246))

# %% [markdown]
# #### Output of the following cell will come as
#
# All test cases passed

# %%
utils.test_sum_of_digits(sum_of_digits)

# %% [markdown]
# # Question 3
# Write a program to check whether a number is prime or not?
#
# A number is prime number if it is divisible by 1 and that number.
#
# A number is prime number if it is not divisible by the numbers other than 1 and that number.

# %%
def check_prime(num):
  """
  This function will check whether a number num is prime or not and return 0 if num is prime else return 1
  """
  #  Consider all number is prime, set nonprime to 0
  nonprime=0
  # Start dividing the number by 2
  dividend=2
  while None:
      if None==0:  # if the number is divided by the dividend, then the number is non prime
          nonprime=None       # set the nonprime to 1
          break            # if the number is divided by a dividend, then no need to check further, break the control
      None          # if the number is not divided by the dividend, then we will check with next value, dividend incremented by 1
  if nonprime==1:
      print("Not Prime")
  else:
      print("Prime")
  # return nonprime
  return nonprime

# %% [markdown]
# ## Test your code

# %%
print(check_prime(15))

# %%
print(check_prime(43))

# %% [markdown]
# #### Output of the following cell will come as
#
# Not Prime
#
# Prime
#
# Not Prime
#
# Prime
#
# Prime
#
# All test cases passed

# %%
utils.test_check_prime(check_prime)

# %% [markdown]
# # Question 4
# Write a program to add all prime numbers between 3 to num.
# if num=10
# then prime number between 3 to 10 are: 3 5 7
#
# 3+5+7=15

# %%
def all_prime_sum(n):
  """
  This function will add all prime numbers between 3 to n and return the sum of all prime numbers as sum1
  """
  sum1=0
  for num in range(3,n+1):  #check all number from 3 to num, if the number is prime then add it
    nonprime=0
    # Start dividing the number by 2
    dividend=2
    while None:
      if None:  # if the number is divided by the dividend, then the number is non prime
          None       # set the nonprime to 1
          break            # if the number is divided by a dividend, then no need to check further, break the control
      dividend+=1          # if the number is not divided by the dividend, then we will check with next value, dividend incremented by 1
    if nonprime==0:        #if the number is prime then add it
      None            #add the prime numbers
  return sum1

# %% [markdown]
# ## Test your code

# %%
print(all_prime_sum(20))

# %% [markdown]
# #### Output of the following cell will come as
#
# All test cases passed

# %%
utils.test_all_prime_sum(all_prime_sum)

# %% [markdown]
# # <font color='green'> Congratulations! You have finished your first graded assignment assignment</font>
