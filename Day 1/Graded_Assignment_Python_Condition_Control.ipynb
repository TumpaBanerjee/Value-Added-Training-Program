# %% [markdown]
# ---
#
#
# # Assignment: Introduction to Python
# # Name:
# # Roll No:
#
#
# ---
#
#
#
# # Instructions:
# # 1. Do not modify given code unless asked
# # 2. Write your answer in marked sections
# # 3. Run all cells before submitting

# %% [markdown]
# ## Introduction
# How to use this Notebook
#
# Do not change content of any cell unless you are asking to do.
# You have to add one or two line of code in the cell followed by the markdown "Question".
#
# Next to exercise cell there is a testing cell which will test your code.
#
# ### <font color='red'> Replace your code with None
#
# _______________________________________________________________

# %%
# !wget https://raw.githubusercontent.com/TumpaBanerjee/Value-Added-Training-Program/main/Day%201/utils1.py
# Out:
# --2026-04-01 10:58:01--  https://raw.githubusercontent.com/TumpaBanerjee/Value-Added-Training-Program/main/Day%201/utils1.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1335 (1.3K) [text/plain]
# Saving to: ‘utils1.py’
#
# utils1.py           100%[===================>]   1.30K  --.-KB/s    in 0s
#
# 2026-04-01 10:58:01 (47.6 MB/s) - ‘utils1.py’ saved [1335/1335]

# %% [markdown]
# ## Import required library or module

# %%
import utils1

# %% [markdown]
# ## Question 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def insurance_eligibility(mar,sex,age):
    """
mar: represent marital status of driver,1 for married, 0 for unmarried
sex: represent sex of driver, 'M' for male, 'F' for female
age: represent age of driver, will take real value
This function will check eligibity of the driver for insurance 1 for eligible, 0 for not eligible, -1 for other cases
    """
    # set eligible to -1 by default
    eligible=None
    # check whether married, mar=1 for married
    if None:
        eligible= # set to eligible to 1
    elif None: # check whether the person is unmarried, mar=0 for unmarried
        if sex=='M':
            if age>30:
                eligible=1
            else:
                eligible=0
        elif None: # check whether the person is female
            if None: # check whether the person's age is greater than 25
                eligible=None  # set to eligible to 1
            else:
                eligible=None    # unmarried female, ge not greater than 25 is not eligible for insurance, set to eligible to 1
        else:
            print("undefined sex")

    else:
        print("undefind marrital status")
    return eligible

# %% [markdown]
# ### Test your code

# %%
print(insurance_eligibility(mar=1,sex='M',age=20))
# Out:
# 1

# %%
utils1.test_insurance_provider(insurance_eligibility)

# %% [markdown]
# ## Question 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def scholarship_calculator(marks,income,cast):
    """
marks: represent marks of the candidate
income: represent represent family income
cast: represent represent cast of the candidate,'C' for SC, 'T' for ST, 'G' for General
This function will check eligibity of the candidate for scholarship and return scholarship amount
payable of the candidate. payable amount
will be 0 for not eligible candidate
    """
    # set scholarship amount is 200000.00
    scholarship_amount=None
    #by default payable amount is 0
    payable=None
    if None:    #check whether student obtained marks greater than 85
        if None:   #check whether income is upto 200000.00
            if cast=='C' or cast=='T':
                payable=None   # Sc, ST candidate having marks greater than 85 and family income upto 200000.00 will get full scholarship
            elif cast=='G':
                payable=None   # General candidate having marks greater than 85 and family income upto 200000.00 will get 75% scholarship
            else:
                print("Wrong data")

        elif None:  #check whether income is upto 500000.00
            payable=scholarship_amount*0.5   # candidtae having marks greater than 85 and family income more than 200000.00 will get 50% scholarship
        else:
            print('Not eligible')
            payable=0
    elif None:  #check whether student obtained marks greater than 55 and less than 85
        if None:   #check whether income is upto 200000.00
            if None:  # check whether student is SC or ST
                payable=None   # Sc, ST candidate having marks greater than 55 and family income upto 200000.00 will get 50% scholarship
            elif cast=='G':
                payable=None  # General candidate having marks greater than 55 and family income upto 200000.00 will get 25% scholarship
            else:
                print("Wrong data")
                payable=0
        else:
            print('Not eligible')  #candidate having marks greater than 55 and family income not less than 200000.00, is not eligible
            payable=0
    else:
        print('Not eligible') #candidate having marks less than 55 is not eligible
        payable=0
    return payable

# %% [markdown]
# ## Test your code

# %%
scholarship_calculator(marks=78,income=350000,cast='G')

# %%
utils1.test_scholarship_amount_function(scholarship_calculator)

# %% [markdown]
# # Question 3
# A library charges a fine for every book returned late. For first 5 days the fine is 50 paise, for 6-10 days fine is one rupee and above 10 days fine is 5 rupees. If you return the book after 30 days your membership will be cancelled. Write a program to accept the number of days the member is late to return the book and display the fine or the appropriate message.

# %% [markdown]
# # Question 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <font color='green'> Congratulations! You have finished your first graded assignment assignment</font>
