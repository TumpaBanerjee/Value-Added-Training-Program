# %% [markdown]
# # =========================================
# # Assignment: Introduction to Python
# # Name:
# # Roll No:
# # =========================================
#
# # Instructions:
# # 1. Do not modify given code unless asked
# # 2. Write your answer in marked sections
# # 3. Run all cells before submitting

# %% [markdown]
# # Table of Contents
#
# -[Introduction](#Introduction)
#
# -[Question 1](#Question 1)
#
# -[Question 2](#Question 2)
#
# -[Question 3](#Question 3)
#
# -[Question 4](#Question 4)

# %% [markdown]
# ## Introduction
# How to use this Notebook
#
# Do not change content of any cell unless you are asking to do.
# You have to add one or two line of code in the cell followed by the markdown "Question".
#
# Next to exercise cell there is a testing cell which will test your code.
#
# ### <font color='red'> Replace your code with None
#
# _______________________________________________________________

# %%
# !wget https://raw.githubusercontent.com/TumpaBanerjee/Value-Added-Training-Program/main/Day%201/utils.py
# Out:
# --2026-03-29 15:30:15--  https://raw.githubusercontent.com/TumpaBanerjee/Value-Added-Training-Program/main/Day%201/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1972 (1.9K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   1.93K  --.-KB/s    in 0s
#
# 2026-03-29 15:30:15 (32.7 MB/s) - ‘utils.py’ saved [1972/1972]

# %% [markdown]
# ## Import required library or module

# %%
import utils

# %% [markdown]
# ## Question 1
# #### Write the code of adding two number
# Write single line of code to add identifier $id1$ and $id2$

# %%
def addition(id1,id2):
  """
  This function will add the identifiers id1 and id2 and will return the result
  You have to change the None with your code
  The function will return the result.
  Cell followed by this cell is for your testing purpose
  """
  flag=0

  # Write single line of code, replace None with your code
  result=None

  return flag,result

# %%
print(addition(34,78)[1])
# Out:
# 112

# %%
addition(10,20)
# Out:
# (0, 30)

# %%
utils.test_sum_function(addition)
# Out:
# All Test cases passed

# %% [markdown]
# ## Question 2
# #### Write the code of subtracting identifier $id1$ from identifer $id2$

# %%
def subtraction(id1,id2):
  """
  This function will subtract the value of the identifiers id2 from the id2 and will return the result
  You have to change the None with your code
  The function will return the result.
  Cell followed by this cell is for your testing purpose
  """
  flag=0

  # Write single line of code, replace None with your code
  result=None

  return flag,result

# %%
print(addition(34,78)[1])

# %%
utils.test_sub_function(subtraction)

# %% [markdown]
# ## Question 3
# Write the code of multiplication

# %%
def multiplication(id1,id2):
  """
  This function will multiply the value of the identifiers id2 with the id2 and will return the result
  You have to change the None with your code
  The function will return the result.
  Cell followed by this cell is for your testing purpose
  """
  flag=0

  # Write single line of code, replace None with your code
  result=None

  return flag,result

# %%
print(multiplication(32,90)[1])

# %%
utils.test_mul_function(multiplication)

# %% [markdown]
# ## Question 4
# Write code for division

# %%
def division(dividend,divisor):
  """
  This function will dividend by the divisor and will return the result
  You have to change the None with your code
  The function will return the result.
  Cell followed by this cell is for your testing purpose
  """
  flag=0

  # Write single line of code, replace None with your code
  result=None

  return flag,result

# %%
print(division(20,10))

# %%
utils.test_div_function(division)
