# %% [markdown]
# # Python Programming: An introduction
# This practice assignment will introduce you with input, output functions, variables and operators in Python

# %% [markdown]
# ## Output function
# $print()$ function is used to print the output at the console.
# The Python print() function has five parameters, which are defined as follows in its syntax:
#
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)

# %%
print('Ram')
print('sita')
# Out:
# Ram
# sita

# %%
print('Ram',end='')
print('sita')
# Out:
# Ramsita

# %% [markdown]
# ## Input Function
# $input()$ function is used to take input from user through keyboard.
#
# input() take input from the keyboard and return as string.

# %%
input()
# Out:
# 21
# '21'

# %%
num=input()
print(num)
# Out:
# 65
# 65

# %%
st1=input('Enter your name')
print('Hello ',st1)
# Out:
# Enter your nameram
# Hello  ram

# %%
num1=input('Enter first number')
num2=input('Enter second number')
print(num1+num2)
# Out:
# Enter first number23
# Enter second number45
# 2345

# %% [markdown]
# ## Type conversion
# We need to convert an input to a required type as input function return inputs as string

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter second number'))
print('Sum=', num1+num2)
# Out:
# Enter first number53
# Enter second number96
# 149

# %% [markdown]
# ## Formatted String Literals
# Formatted string literals (also called f-strings for short) let you include the value of Python expressions inside a string by prefixing the string with f or F and writing expressions as {expression}.
#
# An optional format specifier can follow the expression. This allows greater control over how the value is formatted.

# %%
num=10
print(f'one third of the given number is {num/3}')
# Out:
# one third of the given number is 3.3333333333333335

# %%
num=10
print(f'one third of the given number is {num/3:.3f}')
# Out:
# one third of the given number is 3.333

# %% [markdown]
# ## The String format() Method
# Basic usage of the str.format() method looks like this:

# %%
num=10
print('one third of {} is {}'.format(num,num/3))
# Out:
# one third of 10 is 3.3333333333333335

# %%
num=10
print('one third of {0} is {1}'.format(num,num/3))
# Out:
# one third of 10 is 3.3333333333333335

# %% [markdown]
# ## Old string formatting
# The % operator (modulo) can also be used for string formatting. Given format % values (where format is a string), % conversion specifications in format are replaced with zero or more elements of values. This operation is commonly known as string interpolation.

# %%
num=10
print('one third of the given number is:',num/3)
# Out:
# one third of the given number is:. 3.3333333333333335

# %% [markdown]
# ## Row String

# %%
print(r'Hello "Rahul" how are you')
# Out:
# Hello "Rahul" how are you

# %% [markdown]
# # Python Operators

# %% [markdown]
# Python operators enable you to perform computations by combining objects and operators into expressions. Understanding Python operators is essential for manipulating data effectively.

# %% [markdown]
# In programming, an operator is usually a symbol or combination of symbols that allows you to perform a specific operation. This operation can act on one or more operands. If the operation involves a single operand, then the operator is unary. If the operator involves two operands, then the operator is binary.

# %% [markdown]
# ## Unary Operators

# %%
num=29
print('The given number is:',num)
num1=-num
print(f'Negative of the given number is {-num}')
# Out:
# The given number is: 29
# Negative of the given number is -29

# %% [markdown]
# ## Arithmatic Operators
# Python Arithmetic operators are used to perform basic mathematical operations like addition(+), subtraction(-), multiplication(*) and division(/).

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
sum=num1+num2
print(sum)
# Out:
# Enter first numer23
# Enter first numer43
# 66

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
sub=num1-num2
print(sub)
# Out:
# Enter first numer36
# Enter first numer58
# -22

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
prod=num1*num2
print(prod)
# Out:
# Enter first numer25
# Enter first numer63
# 1575

# %% [markdown]
# ### Division
# $num1/num2$ The quotient of $num1$ divided by $num2$, expressed as a float

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
div=num1/num2
print(div)
# Out:
# Enter first numer58
# Enter first numer3
# 19.333333333333332

# %% [markdown]
# ### Floor Division
# $num1//num2$ The quotient of $num1$ divided by $num2$, rounded to the next smallest whole number

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
div=num1//num2
print(div)
# Out:
# Enter first number25
# Enter first number3
# 8

# %% [markdown]
# ### Exponentiation
# $num1**num2$, results $num1$ raised to the power of $num2$

# %%
num1=int(input('Enter first number'))
num2=int(input('Enter first number'))
div=num1**num2
print(div)
# Out:
# Enter first number25
# Enter first number3
# 15625

# %% [markdown]
# ### Bitwise Operators
# Python Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers.
#
# Bitwise Operators in Python are as follows:
#
# 1. Bitwise NOT
# 2. Bitwise Shift
# 3. Bitwise AND
# 4. Bitwise XOR
# 5. Bitwise OR

# %% [markdown]
# ## Bitwise Not
# 6 = 00000110
# Bitwise NOT flips every bit: 00000110  →  11111001
# In Python (and most systems), negative numbers are stored using the Two's complement.
# Take the binary: 11111001
#
# Flip bits → 00000110
#
# Add 1 → 00000111
#
# Convert to decimal → 7
#
# So: 11111001 = -7

# %%
num1=6
num2=5
not_oprt=~num1
print(not_oprt)
# Out:
# -7

# %% [markdown]
# ## Bitwise AND
# 6-> 00000110
#
# 5-> 00000101
#
#
# ---
# and 00000100 -> 4

# %%
and_oprt=num1&num2
print(and_oprt)
# Out:
# 4

# %% [markdown]
# ## Bitwise OR
# 6-> 00000110
#
# 5-> 00000101
#
#
# ---
# or   00000111 -> 7

# %%
or_oprt=num1|num2
print(or_oprt)
# Out:
# 7

# %% [markdown]
# ## Bitwise AND
# 6-> 00000110
#
# 5-> 00000101
#
#
# ---
# xor 00000011 ->3

# %%
xor_oprt=num1^num2
print(xor_oprt)
# Out:
# 3

# %% [markdown]
# ## Bitwise left shift
# 8-> 00001000<<2 -> 00100000 -> 32

# %%
num1=8
print(num1<<2)
# Out:
# 32

# %% [markdown]
# ## Bitwise left shift
# 8-> 00001000>> 2 -> 00000010 -> 2

# %%
num1=8
print(num1>>2)
# Out:
# 2

# %% [markdown]
# ### Write a Python program to convert temparature from celcious to farenhite.
# input:
# Enter temparature in celcious: 65
#
# output:
# Your temparature is: 149.0 F

# %%
#take temparature in celcioue
cel=

# convert temparature from celcious to farenhite
faren=

# print temparature in farenhite
print()
# Out:
# Enter temparature in celcious100
# Your temparature is:212.0F

# %% [markdown]
# ## <font color='green'> Congratulations! You have completed your practice assignment
